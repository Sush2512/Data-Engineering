# %%
# Import the API key from api_config.py
import pandas as pd
from api_config import *
import requests

# Define the API URL and parameters
url = "https://aerodatabox.p.rapidapi.com/airports/search/location/52.31/13.24/km/50/16"
querystring = {"withFlightInfoOnly": "true"}

# Use the API key from the imported config file
headers = {
    "X-RapidAPI-Key": RAPIDAPI_KEY,
    "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

# Make the request and print the response
response = requests.get(url, headers=headers, params=querystring)
print(response.text)
# Out:
# {"searchBy":{"lat":52.31,"lon":13.24},"count":1,"items":[{"icao":"EDDB","iata":"BER","name":"Berlin Brandenburg","shortName":"Brandenburg","municipalityName":"Berlin","location":{"lat":52.35139,"lon":13.493889},"countryCode":"DE","timeZone":"Europe/Berlin"}]}

# %%
response.json()
# Out:
# {'searchBy': {'lat': 52.31, 'lon': 13.24},
#  'count': 1,
#  'items': [{'icao': 'EDDB',
#    'iata': 'BER',
#    'name': 'Berlin Brandenburg',
#    'shortName': 'Brandenburg',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 52.35139, 'lon': 13.493889},
#    'countryCode': 'DE',
#    'timeZone': 'Europe/Berlin'}]}

# %%
pd.json_normalize(response.json()['items'])
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
#
#         timeZone  location.lat  location.lon
# 0  Europe/Berlin      52.35139     13.493889

# %%
def icao_airport_codes(latitudes, longitudes):

  #assert len(latitudes) == len(longitudes)

  list_for_df = []

  for index, value in enumerate(latitudes):

    url = f"https://aerodatabox.p.rapidapi.com/airports/search/location/{value}/{longitudes[index]}/km/100/16"

    querystring = {"withFlightInfoOnly":"true"}

    headers = {
    "X-RapidAPI-Key": RAPIDAPI_KEY,
    "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
    }

    response = requests.request("GET", url, headers=headers, params=querystring)

    list_for_df.append(pd.json_normalize(response.json()['items']))

  return pd.concat(list_for_df, ignore_index=True)

# %%
# coordinates for Berlin, Paris, London
latitudes = [52.5200, 48.8567, 51.5072]
longitudes = [13.4050, 2.3522, -0.1275]

icao_airport_codes(latitudes, longitudes)
# Out:
#     icao iata                                 name             shortName  \
# 0   EDDB  BER                   Berlin Brandenburg           Brandenburg
# 1   LFPB  LBG                    Paris -Le Bourget           -Le Bourget
# 2   LFPO  ORY                          Paris -Orly                 -Orly
# 3   LFPG  CDG              Paris Charles de Gaulle     Charles de Gaulle
# 4   LFOB  BVA  Beauvais/Tillé Paris Beauvais Tillé  Paris Beauvais Tillé
# 5   EGLC  LCY                          London City                  City
# 6   EGLL  LHR                      London Heathrow              Heathrow
# 7   EGKR  KRH                    Redhill Aerodrome             Aerodrome
# 8   EGKK  LGW                       London Gatwick               Gatwick
# 9   EGGW  LTN                         London Luton                 Luton
# 10  EGSS  STN                      London Stansted              Stansted
# 11  EGMC  SEN                            Southend               Southend
#
#    municipalityName countryCode       timeZone  location.lat  location.lon
# 0            Berlin          DE  Europe/Berlin      52.35139     13.493889
# 1             Paris          FR   Europe/Paris      48.96940      2.441390
# 2             Paris          FR   Europe/Paris      48.72530      2.359440
# 3             Paris          FR   Europe/Paris      49.01280      2.549999
# 4    Beauvais/Tillé          FR   Europe/Paris      49.45440      2.112780
# 5            London          GB  Europe/London      51.50530      0.055277
# 6            London          GB  Europe/London      51.47060     -0.461941
# 7           Redhill          GB  Europe/London      51.21360     -0.138611
# 8            London          GB  Europe/London      51.14810     -0.190277
# 9            London          GB  Europe/London      51.87470     -0.368333
# 10           London          GB  Europe/London      51.88500      0.234999
# 11         Southend          GB  Europe/London      51.57140      0.695555

# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

# %%
# Defining the parameters

icao = "EDDB" # For Berlin airport
date = datetime.now().date()
time_1 = "00:00"
time_2 = "11:59"

url =  f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{date}T{time_1}/{date}T{time_2}"

querystring = {"withLeg":"true",
               "direction":"Arrival",
               "withCancelled":"false",
               "withCodeshared":"true",
               "withCargo":"false",
               "withPrivate":"false"}

headers = {
     "X-RapidAPI-Key": RAPIDAPI_KEY,
     "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
    }

response = requests.request("GET",
                            url,
                            headers = headers,
                            params = querystring)

flights_json = response.json()

flights_json
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'LTFH',
#      'iata': 'SZF',
#      'name': 'Samsun',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-09-11 01:10Z',
#      'local': '2024-09-11 04:10+03:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 04:45Z',
#      'local': '2024-09-11 06:45+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:11Z',
#      'local': '2024-09-11 06:11+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:18Z',
#      'local': '2024-09-11 06:18+02:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 1768',
#    'callSign': 'SXS6JD',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-SPJ', 'modeS': '4BCE0A', 'model': 'Boeing 737'},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'departure': {'airport': {'icao': 'KEWR',
#      'iata': 'EWR',
#      'name': 'Newark',
#      'timeZone': 'America/New_York'},
#     'scheduledTime': {'utc': '2024-09-10 21:15Z',
#      'local': '2024-09-10 17:15-04:00'},
#     'revisedTime': {'utc': '2024-09-10 22:03Z',
#      'local': '2024-09-10 18:03-04:00'},
#     'runwayTime': {'utc': '2024-09-10 22:03Z',
#      'local': '2024-09-10 18:03-04:00'},
#     'terminal': 'C',
#     'runway': '04R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:53Z',
#      'local': '2024-09-11 06:53+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:59Z',
#      'local': '2024-09-11 06:59+02:00'},
#     'terminal': '1',
#     'gate': 'Y17',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'UA 962',
#    'callSign': 'UAL962',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'N69059', 'modeS': 'A92DDF', 'model': 'Boeing 767-400'},
#    'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#   {'departure': {'airport': {'icao': 'OTHH',
#      'iata': 'DOH',
#      'name': 'Doha',
#      'timeZone': 'Asia/Qatar'},
#     'scheduledTime': {'utc': '2024-09-10 23:20Z',
#      'local': '2024-09-11 02:20+03:00'},
#     'revisedTime': {'utc': '2024-09-10 23:29Z',
#      'local': '2024-09-11 02:29+03:00'},
#     'runwayTime': {'utc': '2024-09-10 23:44Z',
#      'local': '2024-09-11 02:44+03:00'},
#     'terminal': 'NULL',
#     'gate': 'C92',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:20Z',
#      'local': '2024-09-11 07:20+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:58Z',
#      'local': '2024-09-11 06:58+02:00'},
#     'terminal': '1',
#     'gate': 'X07',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'QR 79',
#    'callSign': 'QTR32A',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'A7-BHF', 'modeS': '06A2E9', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}},
#   {'departure': {'airport': {'icao': 'ZBAA',
#      'iata': 'PEK',
#      'name': 'Beijing',
#      'timeZone': 'Asia/Shanghai'},
#     'scheduledTime': {'utc': '2024-09-10 19:10Z',
#      'local': '2024-09-11 03:10+08:00'},
#     'revisedTime': {'utc': '2024-09-10 19:05Z',
#      'local': '2024-09-11 03:05+08:00'},
#     'terminal': '2',
#     'checkInDesk': 'C11-C15',
#     'gate': '10',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 04:45Z',
#      'local': '2024-09-11 06:45+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:02Z',
#      'local': '2024-09-11 07:02+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:02Z',
#      'local': '2024-09-11 07:02+02:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A3',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'HU 489',
#    'callSign': 'CHH489',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'B-6539',
#     'modeS': '780818',
#     'model': 'Airbus A330-300'},
#    'airline': {'name': 'Hainan', 'iata': 'HU', 'icao': 'CHH'}},
#   {'departure': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-09-11 04:20Z',
#      'local': '2024-09-11 06:20+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:21Z',
#      'local': '2024-09-11 06:21+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:21Z',
#      'local': '2024-09-11 06:21+02:00'},
#     'terminal': '3',
#     'checkInDesk': '351-372',
#     'gate': 'F07',
#     'runway': '29',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:30Z',
#      'local': '2024-09-11 07:30+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:13Z',
#      'local': '2024-09-11 07:13+02:00'},
#     'terminal': '1',
#     'gate': 'A01',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 221',
#    'callSign': 'AUA221W',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LXA', 'modeS': '44020A', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-09-11 04:00Z',
#      'local': '2024-09-11 06:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:05Z',
#      'local': '2024-09-11 06:05+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:05Z',
#      'local': '2024-09-11 06:05+02:00'},
#     'terminal': '2D',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:50Z',
#      'local': '2024-09-11 07:50+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 4631',
#    'callSign': 'EJU52BJ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IJX', 'modeS': '440141', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-09-11 04:00Z',
#      'local': '2024-09-11 06:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:05Z',
#      'local': '2024-09-11 06:05+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:05Z',
#      'local': '2024-09-11 06:05+02:00'},
#     'terminal': '2D',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:50Z',
#      'local': '2024-09-11 07:50+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 4631',
#    'callSign': 'EJU52BJ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IJX', 'modeS': '440141', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 04:15Z',
#      'local': '2024-09-11 06:15+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:15Z',
#      'local': '2024-09-11 06:15+02:00'},
#     'terminal': '3',
#     'gate': '156',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:25Z',
#      'local': '2024-09-11 07:25+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:19Z',
#      'local': '2024-09-11 07:19+02:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 5385',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABHF', 'modeS': '3C4906', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 04:15Z',
#      'local': '2024-09-11 06:15+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:15Z',
#      'local': '2024-09-11 06:15+02:00'},
#     'terminal': '3',
#     'gate': '156',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:25Z',
#      'local': '2024-09-11 07:25+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:19Z',
#      'local': '2024-09-11 07:19+02:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2002',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABHF', 'modeS': '3C4906', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'KJFK',
#      'iata': 'JFK',
#      'name': 'New York',
#      'timeZone': 'America/New_York'},
#     'scheduledTime': {'utc': '2024-09-10 21:45Z',
#      'local': '2024-09-10 17:45-04:00'},
#     'revisedTime': {'utc': '2024-09-10 22:21Z',
#      'local': '2024-09-10 18:21-04:00'},
#     'runwayTime': {'utc': '2024-09-10 22:21Z',
#      'local': '2024-09-10 18:21-04:00'},
#     'terminal': '4',
#     'runway': '22R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:50Z',
#      'local': '2024-09-11 07:50+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:21Z',
#      'local': '2024-09-11 07:21+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:29Z',
#      'local': '2024-09-11 07:29+02:00'},
#     'terminal': '1',
#     'gate': 'Y02',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'DL 92',
#    'callSign': 'DAL92',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'N193DN', 'modeS': 'A173A8', 'model': 'Boeing 767-300'},
#    'airline': {'name': 'Delta Air Lines', 'iata': 'DL', 'icao': 'DAL'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 04:15Z',
#      'local': '2024-09-11 06:15+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:40Z',
#      'local': '2024-09-11 06:40+02:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A20',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:25Z',
#      'local': '2024-09-11 07:25+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:34Z',
#      'local': '2024-09-11 07:34+02:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 172',
#    'callSign': 'DLH172',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIRN',
#     'modeS': '3C664E',
#     'model': 'Airbus A321-100'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 04:30Z',
#      'local': '2024-09-11 06:30+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:52Z',
#      'local': '2024-09-11 06:52+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:52Z',
#      'local': '2024-09-11 06:52+02:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:40Z',
#      'local': '2024-09-11 07:40+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:38Z',
#      'local': '2024-09-11 07:38+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:39Z',
#      'local': '2024-09-11 07:39+02:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A1',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 12',
#    'callSign': 'EWG5MK',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OK-TSE', 'modeS': '49D232', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 04:30Z',
#      'local': '2024-09-11 06:30+02:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:05Z',
#      'local': '2024-09-11 08:05+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:50Z',
#      'local': '2024-09-11 07:50+02:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'DX 121',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-JRJ', 'modeS': '45AA4A', 'model': 'ATR 42-300'},
#    'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 04:45Z',
#      'local': '2024-09-11 06:45+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:45Z',
#      'local': '2024-09-11 06:45+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:02Z',
#      'local': '2024-09-11 07:02+02:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A54',
#     'runway': '18',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:55Z',
#      'local': '2024-09-11 07:55+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:52Z',
#      'local': '2024-09-11 07:52+02:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 170',
#    'callSign': 'DLH1PT',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIDB', 'modeS': '3C6482', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Düsseldorf',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 04:45Z',
#      'local': '2024-09-11 06:45+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:57Z',
#      'local': '2024-09-11 06:57+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:06Z',
#      'local': '2024-09-11 07:06+02:00'},
#     'terminal': 'B',
#     'checkInDesk': '151,170',
#     'gate': 'A25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 05:55Z',
#      'local': '2024-09-11 07:55+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:54Z',
#      'local': '2024-09-11 07:54+02:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9048',
#    'callSign': 'GWI52FP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABZN', 'modeS': '3C4B4E', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'EFHK',
#      'iata': 'HEL',
#      'name': 'Helsinki',
#      'timeZone': 'Europe/Helsinki'},
#     'scheduledTime': {'utc': '2024-09-11 04:05Z',
#      'local': '2024-09-11 07:05+03:00'},
#     'revisedTime': {'utc': '2024-09-11 04:01Z',
#      'local': '2024-09-11 07:01+03:00'},
#     'runwayTime': {'utc': '2024-09-11 04:11Z',
#      'local': '2024-09-11 07:11+03:00'},
#     'terminal': '2',
#     'checkInDesk': '211',
#     'gate': '24',
#     'runway': '22R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:05Z',
#      'local': '2024-09-11 08:05+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:57Z',
#      'local': '2024-09-11 07:57+02:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1431',
#    'callSign': 'FIN3AW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LZL',
#     'modeS': '461FA1',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'airport': {'icao': 'ELLX',
#      'iata': 'LUX',
#      'name': 'Luxembourg',
#      'timeZone': 'Europe/Luxembourg'},
#     'scheduledTime': {'utc': '2024-09-11 04:35Z',
#      'local': '2024-09-11 06:35+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:34Z',
#      'local': '2024-09-11 06:34+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:46Z',
#      'local': '2024-09-11 06:46+02:00'},
#     'terminal': 'A',
#     'gate': 'B03',
#     'runway': '24',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:05Z',
#      'local': '2024-09-11 08:05+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:57Z',
#      'local': '2024-09-11 07:57+02:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LG 9471',
#    'callSign': 'LGL91B',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LX-LQA',
#     'modeS': '4D00D5',
#     'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#    'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#   {'departure': {'airport': {'icao': 'UGKO',
#      'iata': 'KUT',
#      'name': 'Kutaisi',
#      'timeZone': 'Asia/Tbilisi'},
#     'scheduledTime': {'utc': '2024-09-11 02:20Z',
#      'local': '2024-09-11 06:20+04:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:30Z',
#      'local': '2024-09-11 08:30+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:59Z',
#      'local': '2024-09-11 07:59+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:06Z',
#      'local': '2024-09-11 08:06+02:00'},
#     'terminal': '2',
#     'gate': 'Z42',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'W6 7909',
#    'callSign': 'WZZ529',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-WDY',
#     'modeS': '4D24D7',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}},
#   {'departure': {'airport': {'icao': 'LIRP',
#      'iata': 'PSA',
#      'name': 'Pisa',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-09-11 04:20Z',
#      'local': '2024-09-11 06:20+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:32Z',
#      'local': '2024-09-11 06:32+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:32Z',
#      'local': '2024-09-11 06:32+02:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:15Z',
#      'local': '2024-09-11 08:15+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:01Z',
#      'local': '2024-09-11 08:01+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:01Z',
#      'local': '2024-09-11 08:01+02:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 9955',
#    'callSign': 'RYR295D',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QBC', 'modeS': '4D2274', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-09-11 05:00Z',
#      'local': '2024-09-11 07:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:09Z',
#      'local': '2024-09-11 07:09+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:10Z',
#      'local': '2024-09-11 07:10+02:00'},
#     'terminal': '3',
#     'checkInDesk': '351-372',
#     'gate': 'F25',
#     'runway': '29',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:10Z',
#      'local': '2024-09-11 08:10+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:03Z',
#      'local': '2024-09-11 08:03+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:03Z',
#      'local': '2024-09-11 08:03+02:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 223',
#    'callSign': 'AUA223',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LBQ', 'modeS': '44004F', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'departure': {'airport': {'icao': 'LIME',
#      'iata': 'BGY',
#      'name': 'Bergamo',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-09-11 04:40Z',
#      'local': '2024-09-11 06:40+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:55Z',
#      'local': '2024-09-11 06:55+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:55Z',
#      'local': '2024-09-11 06:55+02:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:20Z',
#      'local': '2024-09-11 08:20+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:06Z',
#      'local': '2024-09-11 08:06+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:07Z',
#      'local': '2024-09-11 08:07+02:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3312',
#    'callSign': 'RYR7KH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QCD', 'modeS': '4D2242', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LIML',
#      'iata': 'LIN',
#      'name': 'Milan',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-09-11 04:55Z',
#      'local': '2024-09-11 06:55+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:51Z',
#      'local': '2024-09-11 06:51+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:51Z',
#      'local': '2024-09-11 06:51+02:00'},
#     'terminal': 'NULL',
#     'runway': '36',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:35Z',
#      'local': '2024-09-11 08:35+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:09Z',
#      'local': '2024-09-11 08:09+02:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5068',
#    'callSign': 'EJU5068',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LIML',
#      'iata': 'LIN',
#      'name': 'Milan',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-09-11 04:55Z',
#      'local': '2024-09-11 06:55+02:00'},
#     'revisedTime': {'utc': '2024-09-11 04:51Z',
#      'local': '2024-09-11 06:51+02:00'},
#     'runwayTime': {'utc': '2024-09-11 04:51Z',
#      'local': '2024-09-11 06:51+02:00'},
#     'terminal': 'NULL',
#     'runway': '36',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:35Z',
#      'local': '2024-09-11 08:35+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:09Z',
#      'local': '2024-09-11 08:09+02:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5068',
#    'callSign': 'EJU5068',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 05:00Z',
#      'local': '2024-09-11 07:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:00Z',
#      'local': '2024-09-11 07:00+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:28Z',
#      'local': '2024-09-11 07:28+02:00'},
#     'terminal': '2',
#     'runway': '26R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:05Z',
#      'local': '2024-09-11 08:05+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:11Z',
#      'local': '2024-09-11 08:11+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:11Z',
#      'local': '2024-09-11 08:11+02:00'},
#     'terminal': '1',
#     'gate': 'A17',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1928',
#    'callSign': 'DLH7N',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIRY', 'modeS': '3C6659', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LDDU',
#      'iata': 'DBV',
#      'name': 'Dubrovnik',
#      'timeZone': 'Europe/Zagreb'},
#     'scheduledTime': {'utc': '2024-09-11 04:30Z',
#      'local': '2024-09-11 06:30+02:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:40Z',
#      'local': '2024-09-11 08:40+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:17Z',
#      'local': '2024-09-11 08:17+02:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 5979',
#    'callSign': 'RYR5W',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SP-RZE',
#     'modeS': '48C2A4',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LFPO',
#      'iata': 'ORY',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-09-11 05:10Z',
#      'local': '2024-09-11 07:10+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:08Z',
#      'local': '2024-09-11 07:08+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:08Z',
#      'local': '2024-09-11 07:08+02:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:50Z',
#      'local': '2024-09-11 08:50+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:22Z',
#      'local': '2024-09-11 08:22+02:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 4897',
#    'callSign': 'EJU42RU',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ING', 'modeS': '440005', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LFPO',
#      'iata': 'ORY',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-09-11 05:10Z',
#      'local': '2024-09-11 07:10+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:08Z',
#      'local': '2024-09-11 07:08+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:08Z',
#      'local': '2024-09-11 07:08+02:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:50Z',
#      'local': '2024-09-11 08:50+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:22Z',
#      'local': '2024-09-11 08:22+02:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 4897',
#    'callSign': 'EJU42RU',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ING', 'modeS': '440005', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LIPZ',
#      'iata': 'VCE',
#      'name': 'Venice',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-09-11 05:10Z',
#      'local': '2024-09-11 07:10+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:55Z',
#      'local': '2024-09-11 08:55+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:24Z',
#      'local': '2024-09-11 08:24+02:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 4075',
#    'callSign': 'EJU82KJ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LKK', 'modeS': '44061B', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LIPZ',
#      'iata': 'VCE',
#      'name': 'Venice',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-09-11 05:10Z',
#      'local': '2024-09-11 07:10+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:55Z',
#      'local': '2024-09-11 08:55+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:24Z',
#      'local': '2024-09-11 08:24+02:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 4075',
#    'callSign': 'EJU82KJ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LKK', 'modeS': '44061B', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LTAI',
#      'iata': 'AYT',
#      'name': 'Antalya',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-09-11 03:05Z',
#      'local': '2024-09-11 06:05+03:00'},
#     'revisedTime': {'utc': '2024-09-11 03:05Z',
#      'local': '2024-09-11 06:05+03:00'},
#     'runwayTime': {'utc': '2024-09-11 03:37Z',
#      'local': '2024-09-11 06:37+03:00'},
#     'terminal': '1',
#     'checkInDesk': '110-112',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:35Z',
#      'local': '2024-09-11 08:35+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:28Z',
#      'local': '2024-09-11 08:28+02:00'},
#     'terminal': '1',
#     'gate': 'X03',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 5067',
#    'callSign': 'PGT4WR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-NBE',
#     'modeS': '4BB845',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'departure': {'airport': {'icao': 'OEJN',
#      'iata': 'JED',
#      'name': 'Jeddah',
#      'timeZone': 'Asia/Riyadh'},
#     'scheduledTime': {'utc': '2024-09-11 00:55Z',
#      'local': '2024-09-11 03:55+03:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:45Z',
#      'local': '2024-09-11 08:45+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:31Z',
#      'local': '2024-09-11 08:31+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:33Z',
#      'local': '2024-09-11 08:33+02:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'XY 643',
#    'callSign': 'KNE643',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HZ-NS69',
#     'modeS': '717C70',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'flynas', 'iata': 'XY', 'icao': 'KNE'}},
#   {'departure': {'airport': {'icao': 'EGKK',
#      'iata': 'LGW',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-09-11 05:05Z',
#      'local': '2024-09-11 06:05+01:00'},
#     'revisedTime': {'utc': '2024-09-11 05:10Z',
#      'local': '2024-09-11 06:10+01:00'},
#     'runwayTime': {'utc': '2024-09-11 05:12Z',
#      'local': '2024-09-11 06:12+01:00'},
#     'terminal': 'N',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:00Z',
#      'local': '2024-09-11 09:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:37Z',
#      'local': '2024-09-11 08:37+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:43Z',
#      'local': '2024-09-11 08:43+02:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 8629',
#    'callSign': 'EZY19TC',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EZDF', 'modeS': '405635', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-09-11 05:20Z',
#      'local': '2024-09-11 07:20+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:20Z',
#      'local': '2024-09-11 07:20+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:38Z',
#      'local': '2024-09-11 07:38+02:00'},
#     'terminal': 'NULL',
#     'checkInDesk': '1',
#     'gate': 'A71',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:45Z',
#      'local': '2024-09-11 08:45+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:38Z',
#      'local': '2024-09-11 08:38+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:44Z',
#      'local': '2024-09-11 08:44+02:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 974',
#    'callSign': 'SWR97Y',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-IOD', 'modeS': '4B168F', 'model': 'Airbus A321'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 05:45Z',
#      'local': '2024-09-11 07:45+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:45Z',
#      'local': '2024-09-11 07:45+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:57Z',
#      'local': '2024-09-11 07:57+02:00'},
#     'terminal': '1',
#     'checkInDesk': '259-335',
#     'gate': 'A18',
#     'runway': '25C',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:55Z',
#      'local': '2024-09-11 08:55+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:43Z',
#      'local': '2024-09-11 08:43+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:43Z',
#      'local': '2024-09-11 08:43+02:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 174',
#    'callSign': 'DLH4PH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIST', 'modeS': '3C6674', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LIRN',
#      'iata': 'NAP',
#      'name': 'Nápoli',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-09-11 05:00Z',
#      'local': '2024-09-11 07:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:00Z',
#      'local': '2024-09-11 07:00+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:00Z',
#      'local': '2024-09-11 07:00+02:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:20Z',
#      'local': '2024-09-11 09:20+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:46Z',
#      'local': '2024-09-11 08:46+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:48Z',
#      'local': '2024-09-11 08:48+02:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 4265',
#    'callSign': 'EJU4265',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IVQ', 'modeS': '4400C8', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LIRN',
#      'iata': 'NAP',
#      'name': 'Nápoli',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-09-11 05:00Z',
#      'local': '2024-09-11 07:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:00Z',
#      'local': '2024-09-11 07:00+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:00Z',
#      'local': '2024-09-11 07:00+02:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:20Z',
#      'local': '2024-09-11 09:20+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:46Z',
#      'local': '2024-09-11 08:46+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:48Z',
#      'local': '2024-09-11 08:48+02:00'},
#     'terminal': '1',
#     'gate': 'A36',
#     'baggageBelt': 'A4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 4265',
#    'callSign': 'EJU4265',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IVQ', 'modeS': '4400C8', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LTBJ',
#      'iata': 'ADB',
#      'name': 'İzmir',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-09-11 01:25Z',
#      'local': '2024-09-11 04:25+03:00'},
#     'revisedTime': {'utc': '2024-09-11 04:21Z',
#      'local': '2024-09-11 07:21+03:00'},
#     'runwayTime': {'utc': '2024-09-11 04:20Z',
#      'local': '2024-09-11 07:20+03:00'},
#     'terminal': 'I',
#     'checkInDesk': '22',
#     'gate': '104',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 04:30Z',
#      'local': '2024-09-11 06:30+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:50Z',
#      'local': '2024-09-11 08:50+02:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 966',
#    'callSign': 'SXS5D',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-SPO', 'modeS': '4BCE0F', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'departure': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 06:00Z',
#      'local': '2024-09-11 08:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:00Z',
#      'local': '2024-09-11 08:00+02:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:05Z',
#      'local': '2024-09-11 09:05+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:52Z',
#      'local': '2024-09-11 08:52+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:53Z',
#      'local': '2024-09-11 08:53+02:00'},
#     'terminal': '1',
#     'gate': 'A17',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1930',
#    'callSign': 'DLH5LW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AILX', 'modeS': '3C6598', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:45Z',
#      'local': '2024-09-11 07:45+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:45Z',
#      'local': '2024-09-11 07:45+02:00'},
#     'terminal': '2F',
#     'runway': '27L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 06:55Z',
#      'local': '2024-09-11 08:55+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:54Z',
#      'local': '2024-09-11 08:54+02:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1434',
#    'callSign': 'AFR95ZE',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-HDRF', 'modeS': '398E25', 'model': 'Airbus A320'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'ENGM',
#      'iata': 'OSL',
#      'name': 'Oslo',
#      'timeZone': 'Europe/Oslo'},
#     'scheduledTime': {'utc': '2024-09-11 05:30Z',
#      'local': '2024-09-11 07:30+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:21Z',
#      'local': '2024-09-11 07:21+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:36Z',
#      'local': '2024-09-11 07:36+02:00'},
#     'terminal': 'NULL',
#     'checkInDesk': '123',
#     'gate': 'D8',
#     'runway': '19L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:05Z',
#      'local': '2024-09-11 09:05+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:59Z',
#      'local': '2024-09-11 08:59+02:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'DY 1102',
#    'callSign': 'NOZ2XM',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LN-ENO', 'modeS': '47A32E', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 06:10Z',
#      'local': '2024-09-11 08:10+02:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:20Z',
#      'local': '2024-09-11 09:20+02:00'},
#     'revisedTime': {'utc': '2024-09-11 07:12Z',
#      'local': '2024-09-11 09:12+02:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8059',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWN', 'modeS': '3C5EEE', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-09-11 06:19Z',
#      'local': '2024-09-11 08:19+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:19Z',
#      'local': '2024-09-11 08:19+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:19Z',
#      'local': '2024-09-11 08:19+02:00'},
#     'runway': '29',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:18Z',
#      'local': '2024-09-11 09:18+02:00'},
#     'revisedTime': {'utc': '2024-09-11 07:18Z',
#      'local': '2024-09-11 09:18+02:00'},
#     'runwayTime': {'utc': '2024-09-11 07:18Z',
#      'local': '2024-09-11 09:18+02:00'},
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'OEFLL',
#    'callSign': 'OEFLL',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-XOH',
#     'modeS': '44015B',
#     'model': 'Eurocopter AS350'},
#    'airline': {'name': 'OEFLL'}},
#   {'departure': {'airport': {'icao': 'LFMN',
#      'iata': 'NCE',
#      'name': 'Nice',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'revisedTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'runwayTime': {'utc': '2024-09-11 05:15Z',
#      'local': '2024-09-11 07:15+02:00'},
#     'runway': '04R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:20Z',
#      'local': '2024-09-11 09:20+02:00'},
#     'revisedTime': {'utc': '2024-09-11 07:20Z',
#      'local': '2024-09-11 09:20+02:00'},
#     'runwayTime': {'utc': '2024-09-11 07:20Z',
#      'local': '2024-09-11 09:20+02:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'LWG 10B',
#    'callSign': 'LWG10B',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-FOM', 'modeS': '4D2091', 'model': 'EMB-500'},
#    'airline': {'name': 'LWG'}},
#   {'departure': {'airport': {'icao': 'LTFM',
#      'iata': 'IST',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-09-11 04:30Z',
#      'local': '2024-09-11 07:30+03:00'},
#     'revisedTime': {'utc': '2024-09-11 04:40Z',
#      'local': '2024-09-11 07:40+03:00'},
#     'runwayTime': {'utc': '2024-09-11 05:17Z',
#      'local': '2024-09-11 08:17+03:00'},
#     'terminal': 'NULL',
#     'checkInDesk': 'E-F',
#     'gate': 'D6',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:20Z',
#      'local': '2024-09-11 09:20+02:00'},
#     'revisedTime': {'utc': '2024-09-11 07:20Z',
#      'local': '2024-09-11 09:20+02:00'},
#     'terminal': '1',
#     'gate': 'X01',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1721',
#    'callSign': 'THY3CS',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-LLZ', 'modeS': '4BB19A', 'model': 'Boeing 787-9'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'departure': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-09-11 06:26Z',
#      'local': '2024-09-11 08:26+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:26Z',
#      'local': '2024-09-11 08:26+02:00'},
#     'runwayTime': {'utc': '2024-09-11 06:26Z',
#      'local': '2024-09-11 08:26+02:00'},
#     'runway': '24',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:21Z',
#      'local': '2024-09-11 09:21+02:00'},
#     'revisedTime': {'utc': '2024-09-11 07:21Z',
#      'local': '2024-09-11 09:21+02:00'},
#     'runwayTime': {'utc': '2024-09-11 07:21Z',
#      'local': '2024-09-11 09:21+02:00'},
#     'quality': ['Basic', 'Live']},
#    'number': '4U 9RX',
#    'callSign': 'GWI9RX',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWN', 'modeS': '3C5EEE', 'model': 'Airbus A319'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'departure': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:24Z',
#      'local': '2024-09-11 09:24+02:00'},
#     'revisedTime': {'utc': '2024-09-11 07:24Z',
#      'local': '2024-09-11 09:24+02:00'},
#     'runwayTime': {'utc': '2024-09-11 07:24Z',
#      'local': '2024-09-11 09:24+02:00'},
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'VJT 527',
#    'callSign': 'VJT527',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VLK',
#     'modeS': '4D22D6',
#     'model': 'Bombardier Challenger 600'},
#    'airline': {'name': 'VistaJet', 'icao': 'VJT'}},
#   {'departure': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-09-11 06:05Z',
#      'local': '2024-09-11 08:05+02:00'},
#     'revisedTime': {'utc': '2024-09-11 06:05Z',
#      'local': '2024-09-11 08:05+02:00'},
#     'checkInDesk': '3',
#     'gate': 'B41',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 07:40Z',
#      'local': '2024-09-11 09:40+02:00'},
#     'revisedTime': {'utc': '2024-09-11 07:25Z',
#      'local': '2024-09-11 09:25+02:00'},
#     'terminal': '1',
# ...
#      'local': '2024-09-11 09:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 07:17Z',
#      'local': '2024-09-11 09:17+02:00'},
#     'runwayTime': {'utc': '2024-09-11 07:17Z',
#      'local': '2024-09-11 09:17+02:00'},
#     'terminal': '1',
#     'runway': '25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:15Z',
#      'local': '2024-09-11 11:15+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:06Z',
#      'local': '2024-09-11 11:06+02:00'},
#     'terminal': '1',
#     'gate': 'A37',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5082',
#    'callSign': 'EJU34TY',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICN', 'modeS': '44001F', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EGLC',
#      'iata': 'LCY',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-09-11 07:25Z',
#      'local': '2024-09-11 08:25+01:00'},
#     'revisedTime': {'utc': '2024-09-11 07:43Z',
#      'local': '2024-09-11 08:43+01:00'},
#     'runwayTime': {'utc': '2024-09-11 07:48Z',
#      'local': '2024-09-11 08:48+01:00'},
#     'terminal': 'NULL',
#     'gate': '4',
#     'runway': '27',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:10Z',
#      'local': '2024-09-11 11:10+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:08Z',
#      'local': '2024-09-11 11:08+02:00'},
#     'runwayTime': {'utc': '2024-09-11 09:09Z',
#      'local': '2024-09-11 11:09+02:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8491',
#    'callSign': 'CFE76JZ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCAD', 'modeS': '40799C', 'model': 'Embraer 190'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-09-11 08:00Z',
#      'local': '2024-09-11 10:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 08:03Z',
#      'local': '2024-09-11 10:03+02:00'},
#     'runwayTime': {'utc': '2024-09-11 08:04Z',
#      'local': '2024-09-11 10:04+02:00'},
#     'terminal': 'NULL',
#     'checkInDesk': '42-50',
#     'gate': '35',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:30Z',
#      'local': '2024-09-11 11:30+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:13Z',
#      'local': '2024-09-11 11:13+02:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5535',
#    'callSign': 'EJU75ZB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQF', 'modeS': '4403F0', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-09-11 08:00Z',
#      'local': '2024-09-11 10:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 08:03Z',
#      'local': '2024-09-11 10:03+02:00'},
#     'runwayTime': {'utc': '2024-09-11 08:04Z',
#      'local': '2024-09-11 10:04+02:00'},
#     'checkInDesk': '42-50',
#     'gate': '35',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:30Z',
#      'local': '2024-09-11 11:30+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:13Z',
#      'local': '2024-09-11 11:13+02:00'},
#     'terminal': '1',
#     'gate': 'A38',
#     'baggageBelt': 'A4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5535',
#    'callSign': 'EJU75ZB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQF', 'modeS': '4403F0', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-09-11 07:55Z',
#      'local': '2024-09-11 09:55+02:00'},
#     'revisedTime': {'utc': '2024-09-11 08:25Z',
#      'local': '2024-09-11 10:25+02:00'},
#     'runwayTime': {'utc': '2024-09-11 08:25Z',
#      'local': '2024-09-11 10:25+02:00'},
#     'terminal': '1',
#     'checkInDesk': '151-162',
#     'gate': 'C42',
#     'runway': '29',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:15Z',
#      'local': '2024-09-11 11:15+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:15Z',
#      'local': '2024-09-11 11:15+02:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8751',
#    'callSign': 'EWG2NY',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-MLR', 'modeS': '4D23A1', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'airport': {'icao': 'LGTS',
#      'iata': 'SKG',
#      'name': 'Thessaloniki',
#      'timeZone': 'Europe/Athens'},
#     'scheduledTime': {'utc': '2024-09-11 06:55Z',
#      'local': '2024-09-11 09:55+03:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:25Z',
#      'local': '2024-09-11 11:25+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:16Z',
#      'local': '2024-09-11 11:16+02:00'},
#     'terminal': '2',
#     'gate': 'Z29',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1147',
#    'callSign': 'RYR3KZ',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VVK',
#     'modeS': '4D24CC',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik',
#      'timeZone': 'Atlantic/Reykjavik'},
#     'scheduledTime': {'utc': '2024-09-11 06:00Z',
#      'local': '2024-09-11 06:00+00:00'},
#     'revisedTime': {'utc': '2024-09-11 05:54Z',
#      'local': '2024-09-11 05:54+00:00'},
#     'runwayTime': {'utc': '2024-09-11 06:08Z',
#      'local': '2024-09-11 06:08+00:00'},
#     'terminal': 'NULL',
#     'gate': 'C21',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:30Z',
#      'local': '2024-09-11 11:30+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:21Z',
#      'local': '2024-09-11 11:21+02:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'OG 700',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TF-PPD',
#     'modeS': '4CC564',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Ghodawat Enterprises', 'iata': 'OG', 'icao': 'SDG'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2024-09-11 08:15Z',
#      'local': '2024-09-11 10:15+02:00'},
#     'revisedTime': {'utc': '2024-09-11 08:25Z',
#      'local': '2024-09-11 10:25+02:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'C12',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:30Z',
#      'local': '2024-09-11 11:30+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:26Z',
#      'local': '2024-09-11 11:26+02:00'},
#     'terminal': '1',
#     'gate': 'A31',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1775',
#    'callSign': 'KLM1775',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BGB', 'modeS': '484559', 'model': 'Boeing 737'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm',
#      'timeZone': 'Europe/Stockholm'},
#     'scheduledTime': {'utc': '2024-09-11 08:00Z',
#      'local': '2024-09-11 10:00+02:00'},
#     'revisedTime': {'utc': '2024-09-11 07:58Z',
#      'local': '2024-09-11 09:58+02:00'},
#     'runwayTime': {'utc': '2024-09-11 08:08Z',
#      'local': '2024-09-11 10:08+02:00'},
#     'terminal': '5',
#     'checkInDesk': '18-0',
#     'gate': 'D11',
#     'runway': '19R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:35Z',
#      'local': '2024-09-11 11:35+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:31Z',
#      'local': '2024-09-11 11:31+02:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'DY 886',
#    'callSign': 'NOZ886',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SE-RPK', 'modeS': '4ACA0B', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#   {'departure': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:33Z',
#      'local': '2024-09-11 11:33+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:33Z',
#      'local': '2024-09-11 11:33+02:00'},
#     'runwayTime': {'utc': '2024-09-11 09:33Z',
#      'local': '2024-09-11 11:33+02:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'TKJ 86N',
#    'callSign': 'TKJ86N',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-GPE', 'modeS': '4B9E05', 'model': 'Airbus A321'},
#    'airline': {'name': 'TKJ'}},
#   {'departure': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-09-11 06:20Z',
#      'local': '2024-09-11 09:20+03:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:25Z',
#      'local': '2024-09-11 11:25+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:34Z',
#      'local': '2024-09-11 11:34+02:00'},
#     'terminal': '1',
#     'gate': 'N01',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'VF 57',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-GPE', 'modeS': '4B9E05', 'model': 'Airbus A321'},
#    'airline': {'name': 'Ajet', 'iata': 'VF', 'icao': 'VLU'}},
#   {'departure': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-09-11 07:45Z',
#      'local': '2024-09-11 08:45+01:00'},
#     'revisedTime': {'utc': '2024-09-11 08:19Z',
#      'local': '2024-09-11 09:19+01:00'},
#     'runwayTime': {'utc': '2024-09-11 08:20Z',
#      'local': '2024-09-11 09:20+01:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'runway': '27L',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:35Z',
#      'local': '2024-09-11 11:35+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:41Z',
#      'local': '2024-09-11 11:41+02:00'},
#     'runwayTime': {'utc': '2024-09-11 09:43Z',
#      'local': '2024-09-11 11:43+02:00'},
#     'terminal': '1',
#     'gate': 'X03',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 982',
#    'callSign': 'BAW982G',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EUPT', 'modeS': '4008B4', 'model': 'Airbus A319'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'LBBG',
#      'iata': 'BOJ',
#      'name': 'Burgas',
#      'timeZone': 'Europe/Sofia'},
#     'scheduledTime': {'utc': '2024-09-11 07:20Z',
#      'local': '2024-09-11 10:20+03:00'},
#     'terminal': 'NULL',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 10:05Z',
#      'local': '2024-09-11 12:05+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:44Z',
#      'local': '2024-09-11 11:44+02:00'},
#     'runwayTime': {'utc': '2024-09-11 09:46Z',
#      'local': '2024-09-11 11:46+02:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'SR 7401',
#    'callSign': 'SDR70MN',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ASMR', 'modeS': '3C0936', 'model': 'Airbus A320'},
#    'airline': {'name': 'SundAir', 'iata': 'SR', 'icao': 'SDR'}},
#   {'departure': {'airport': {'icao': 'EGPH',
#      'iata': 'EDI',
#      'name': 'Edinburgh',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-09-11 08:05Z',
#      'local': '2024-09-11 09:05+01:00'},
#     'revisedTime': {'utc': '2024-09-11 08:09Z',
#      'local': '2024-09-11 09:09+01:00'},
#     'runwayTime': {'utc': '2024-09-11 08:09Z',
#      'local': '2024-09-11 09:09+01:00'},
#     'terminal': 'NULL',
#     'runway': '24',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 10:05Z',
#      'local': '2024-09-11 12:05+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:49Z',
#      'local': '2024-09-11 11:49+02:00'},
#     'terminal': '2',
#     'gate': 'Z42',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 2376',
#    'callSign': 'RYR2376',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EKR', 'modeS': '4CA811', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LTAI',
#      'iata': 'AYT',
#      'name': 'Antalya',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-09-11 06:00Z',
#      'local': '2024-09-11 09:00+03:00'},
#     'revisedTime': {'utc': '2024-09-11 06:30Z',
#      'local': '2024-09-11 09:30+03:00'},
#     'runwayTime': {'utc': '2024-09-11 07:00Z',
#      'local': '2024-09-11 10:00+03:00'},
#     'terminal': '1',
#     'checkInDesk': '129-131',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:35Z',
#      'local': '2024-09-11 11:35+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:50Z',
#      'local': '2024-09-11 11:50+02:00'},
#     'terminal': '1',
#     'gate': 'X01',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 160',
#    'callSign': 'SXS2SR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-SEJ', 'modeS': '4BCCAA', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm',
#      'timeZone': 'Europe/Stockholm'},
#     'scheduledTime': {'utc': '2024-09-11 08:05Z',
#      'local': '2024-09-11 10:05+02:00'},
#     'revisedTime': {'utc': '2024-09-11 08:01Z',
#      'local': '2024-09-11 10:01+02:00'},
#     'runwayTime': {'utc': '2024-09-11 08:12Z',
#      'local': '2024-09-11 10:12+02:00'},
#     'terminal': '5',
#     'checkInDesk': '71-80',
#     'gate': 'E8',
#     'runway': '19R',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-09-11 09:40Z',
#      'local': '2024-09-11 11:40+02:00'},
#     'revisedTime': {'utc': '2024-09-11 09:53Z',
#      'local': '2024-09-11 11:53+02:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B3',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'SK 2677',
#    'callSign': 'SAS2677',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SE-ROI',
#     'modeS': '4AC9E9',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}}]}

# %%
flights_json.keys()
# Out:
# dict_keys(['arrivals'])

# %%
flights_json["arrivals"]
# Out:
# [{'departure': {'airport': {'icao': 'LTFH',
#     'iata': 'SZF',
#     'name': 'Samsun',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-09-11 01:10Z',
#     'local': '2024-09-11 04:10+03:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 04:45Z',
#     'local': '2024-09-11 06:45+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:11Z',
#     'local': '2024-09-11 06:11+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:18Z',
#     'local': '2024-09-11 06:18+02:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'XQ 1768',
#   'callSign': 'SXS6JD',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-SPJ', 'modeS': '4BCE0A', 'model': 'Boeing 737'},
#   'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#  {'departure': {'airport': {'icao': 'KEWR',
#     'iata': 'EWR',
#     'name': 'Newark',
#     'timeZone': 'America/New_York'},
#    'scheduledTime': {'utc': '2024-09-10 21:15Z',
#     'local': '2024-09-10 17:15-04:00'},
#    'revisedTime': {'utc': '2024-09-10 22:03Z',
#     'local': '2024-09-10 18:03-04:00'},
#    'runwayTime': {'utc': '2024-09-10 22:03Z',
#     'local': '2024-09-10 18:03-04:00'},
#    'terminal': 'C',
#    'runway': '04R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:53Z',
#     'local': '2024-09-11 06:53+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:59Z',
#     'local': '2024-09-11 06:59+02:00'},
#    'terminal': '1',
#    'gate': 'Y17',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'UA 962',
#   'callSign': 'UAL962',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'N69059', 'modeS': 'A92DDF', 'model': 'Boeing 767-400'},
#   'airline': {'name': 'United', 'iata': 'UA', 'icao': 'UAL'}},
#  {'departure': {'airport': {'icao': 'OTHH',
#     'iata': 'DOH',
#     'name': 'Doha',
#     'timeZone': 'Asia/Qatar'},
#    'scheduledTime': {'utc': '2024-09-10 23:20Z',
#     'local': '2024-09-11 02:20+03:00'},
#    'revisedTime': {'utc': '2024-09-10 23:29Z',
#     'local': '2024-09-11 02:29+03:00'},
#    'runwayTime': {'utc': '2024-09-10 23:44Z',
#     'local': '2024-09-11 02:44+03:00'},
#    'terminal': 'NULL',
#    'gate': 'C92',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:20Z',
#     'local': '2024-09-11 07:20+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:58Z',
#     'local': '2024-09-11 06:58+02:00'},
#    'terminal': '1',
#    'gate': 'X07',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'QR 79',
#   'callSign': 'QTR32A',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'A7-BHF', 'modeS': '06A2E9', 'model': 'Boeing 787-9'},
#   'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'}},
#  {'departure': {'airport': {'icao': 'ZBAA',
#     'iata': 'PEK',
#     'name': 'Beijing',
#     'timeZone': 'Asia/Shanghai'},
#    'scheduledTime': {'utc': '2024-09-10 19:10Z',
#     'local': '2024-09-11 03:10+08:00'},
#    'revisedTime': {'utc': '2024-09-10 19:05Z',
#     'local': '2024-09-11 03:05+08:00'},
#    'terminal': '2',
#    'checkInDesk': 'C11-C15',
#    'gate': '10',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 04:45Z',
#     'local': '2024-09-11 06:45+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:02Z',
#     'local': '2024-09-11 07:02+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:02Z',
#     'local': '2024-09-11 07:02+02:00'},
#    'terminal': '1',
#    'gate': 'X17',
#    'baggageBelt': 'A3',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'HU 489',
#   'callSign': 'CHH489',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'B-6539', 'modeS': '780818', 'model': 'Airbus A330-300'},
#   'airline': {'name': 'Hainan', 'iata': 'HU', 'icao': 'CHH'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-09-11 04:20Z',
#     'local': '2024-09-11 06:20+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:21Z',
#     'local': '2024-09-11 06:21+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:21Z',
#     'local': '2024-09-11 06:21+02:00'},
#    'terminal': '3',
#    'checkInDesk': '351-372',
#    'gate': 'F07',
#    'runway': '29',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:30Z',
#     'local': '2024-09-11 07:30+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:13Z',
#     'local': '2024-09-11 07:13+02:00'},
#    'terminal': '1',
#    'gate': 'A01',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 221',
#   'callSign': 'AUA221W',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LXA', 'modeS': '44020A', 'model': 'Airbus A320'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#  {'departure': {'airport': {'icao': 'LFPG',
#     'iata': 'CDG',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-09-11 04:00Z',
#     'local': '2024-09-11 06:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:05Z',
#     'local': '2024-09-11 06:05+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:05Z',
#     'local': '2024-09-11 06:05+02:00'},
#    'terminal': '2D',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:50Z',
#     'local': '2024-09-11 07:50+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'terminal': '1',
#    'gate': 'A36',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 4631',
#   'callSign': 'EJU52BJ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IJX', 'modeS': '440141', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LFPG',
#     'iata': 'CDG',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-09-11 04:00Z',
#     'local': '2024-09-11 06:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:05Z',
#     'local': '2024-09-11 06:05+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:05Z',
#     'local': '2024-09-11 06:05+02:00'},
#    'terminal': '2D',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:50Z',
#     'local': '2024-09-11 07:50+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'terminal': '1',
#    'gate': 'A36',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 4631',
#   'callSign': 'EJU52BJ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IJX', 'modeS': '440141', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 04:15Z',
#     'local': '2024-09-11 06:15+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:15Z',
#     'local': '2024-09-11 06:15+02:00'},
#    'terminal': '3',
#    'gate': '156',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:25Z',
#     'local': '2024-09-11 07:25+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:19Z',
#     'local': '2024-09-11 07:19+02:00'},
#    'terminal': '1',
#    'gate': 'A35',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 5385',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABHF', 'modeS': '3C4906', 'model': 'Airbus A320'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EDDS',
#     'iata': 'STR',
#     'name': 'Stuttgart',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 04:15Z',
#     'local': '2024-09-11 06:15+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:15Z',
#     'local': '2024-09-11 06:15+02:00'},
#    'terminal': '3',
#    'gate': '156',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:25Z',
#     'local': '2024-09-11 07:25+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:19Z',
#     'local': '2024-09-11 07:19+02:00'},
#    'terminal': '1',
#    'gate': 'A35',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 2002',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABHF', 'modeS': '3C4906', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'KJFK',
#     'iata': 'JFK',
#     'name': 'New York',
#     'timeZone': 'America/New_York'},
#    'scheduledTime': {'utc': '2024-09-10 21:45Z',
#     'local': '2024-09-10 17:45-04:00'},
#    'revisedTime': {'utc': '2024-09-10 22:21Z',
#     'local': '2024-09-10 18:21-04:00'},
#    'runwayTime': {'utc': '2024-09-10 22:21Z',
#     'local': '2024-09-10 18:21-04:00'},
#    'terminal': '4',
#    'runway': '22R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:50Z',
#     'local': '2024-09-11 07:50+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:21Z',
#     'local': '2024-09-11 07:21+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:29Z',
#     'local': '2024-09-11 07:29+02:00'},
#    'terminal': '1',
#    'gate': 'Y02',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'DL 92',
#   'callSign': 'DAL92',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'N193DN', 'modeS': 'A173A8', 'model': 'Boeing 767-300'},
#   'airline': {'name': 'Delta Air Lines', 'iata': 'DL', 'icao': 'DAL'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 04:15Z',
#     'local': '2024-09-11 06:15+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:40Z',
#     'local': '2024-09-11 06:40+02:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A20',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:25Z',
#     'local': '2024-09-11 07:25+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:34Z',
#     'local': '2024-09-11 07:34+02:00'},
#    'terminal': '1',
#    'gate': 'B07',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 172',
#   'callSign': 'DLH172',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIRN', 'modeS': '3C664E', 'model': 'Airbus A321-100'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 04:30Z',
#     'local': '2024-09-11 06:30+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:52Z',
#     'local': '2024-09-11 06:52+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:52Z',
#     'local': '2024-09-11 06:52+02:00'},
#    'terminal': '1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:40Z',
#     'local': '2024-09-11 07:40+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:38Z',
#     'local': '2024-09-11 07:38+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:39Z',
#     'local': '2024-09-11 07:39+02:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A1',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 12',
#   'callSign': 'EWG5MK',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OK-TSE', 'modeS': '49D232', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EDDR',
#     'iata': 'SCN',
#     'name': 'Saarbrücken',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 04:30Z',
#     'local': '2024-09-11 06:30+02:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:05Z',
#     'local': '2024-09-11 08:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:50Z',
#     'local': '2024-09-11 07:50+02:00'},
#    'terminal': '2',
#    'gate': 'Z36',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'DX 121',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OY-JRJ', 'modeS': '45AA4A', 'model': 'ATR 42-300'},
#   'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 04:45Z',
#     'local': '2024-09-11 06:45+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:45Z',
#     'local': '2024-09-11 06:45+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:02Z',
#     'local': '2024-09-11 07:02+02:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A54',
#    'runway': '18',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:55Z',
#     'local': '2024-09-11 07:55+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:52Z',
#     'local': '2024-09-11 07:52+02:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 170',
#   'callSign': 'DLH1PT',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIDB', 'modeS': '3C6482', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'EDDL',
#     'iata': 'DUS',
#     'name': 'Düsseldorf',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 04:45Z',
#     'local': '2024-09-11 06:45+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:57Z',
#     'local': '2024-09-11 06:57+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:06Z',
#     'local': '2024-09-11 07:06+02:00'},
#    'terminal': 'B',
#    'checkInDesk': '151,170',
#    'gate': 'A25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 05:55Z',
#     'local': '2024-09-11 07:55+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:54Z',
#     'local': '2024-09-11 07:54+02:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 9048',
#   'callSign': 'GWI52FP',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ABZN', 'modeS': '3C4B4E', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'EFHK',
#     'iata': 'HEL',
#     'name': 'Helsinki',
#     'timeZone': 'Europe/Helsinki'},
#    'scheduledTime': {'utc': '2024-09-11 04:05Z',
#     'local': '2024-09-11 07:05+03:00'},
#    'revisedTime': {'utc': '2024-09-11 04:01Z',
#     'local': '2024-09-11 07:01+03:00'},
#    'runwayTime': {'utc': '2024-09-11 04:11Z',
#     'local': '2024-09-11 07:11+03:00'},
#    'terminal': '2',
#    'checkInDesk': '211',
#    'gate': '24',
#    'runway': '22R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:05Z',
#     'local': '2024-09-11 08:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:57Z',
#     'local': '2024-09-11 07:57+02:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'AY 1431',
#   'callSign': 'FIN3AW',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OH-LZL',
#    'modeS': '461FA1',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#  {'departure': {'airport': {'icao': 'ELLX',
#     'iata': 'LUX',
#     'name': 'Luxembourg',
#     'timeZone': 'Europe/Luxembourg'},
#    'scheduledTime': {'utc': '2024-09-11 04:35Z',
#     'local': '2024-09-11 06:35+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:34Z',
#     'local': '2024-09-11 06:34+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:46Z',
#     'local': '2024-09-11 06:46+02:00'},
#    'terminal': 'A',
#    'gate': 'B03',
#    'runway': '24',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:05Z',
#     'local': '2024-09-11 08:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:57Z',
#     'local': '2024-09-11 07:57+02:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LG 9471',
#   'callSign': 'LGL91B',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LX-LQA',
#    'modeS': '4D00D5',
#    'model': 'De Havilland Canada DHC-8-400 Dash 8Q'},
#   'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#  {'departure': {'airport': {'icao': 'UGKO',
#     'iata': 'KUT',
#     'name': 'Kutaisi',
#     'timeZone': 'Asia/Tbilisi'},
#    'scheduledTime': {'utc': '2024-09-11 02:20Z',
#     'local': '2024-09-11 06:20+04:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:30Z',
#     'local': '2024-09-11 08:30+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:59Z',
#     'local': '2024-09-11 07:59+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:06Z',
#     'local': '2024-09-11 08:06+02:00'},
#    'terminal': '2',
#    'gate': 'Z42',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'W6 7909',
#   'callSign': 'WZZ529',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-WDY', 'modeS': '4D24D7', 'model': 'Airbus A321 NEO'},
#   'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}},
#  {'departure': {'airport': {'icao': 'LIRP',
#     'iata': 'PSA',
#     'name': 'Pisa',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-09-11 04:20Z',
#     'local': '2024-09-11 06:20+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:32Z',
#     'local': '2024-09-11 06:32+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:32Z',
#     'local': '2024-09-11 06:32+02:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:15Z',
#     'local': '2024-09-11 08:15+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:01Z',
#     'local': '2024-09-11 08:01+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:01Z',
#     'local': '2024-09-11 08:01+02:00'},
#    'terminal': '2',
#    'gate': 'Z30',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 9955',
#   'callSign': 'RYR295D',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-QBC', 'modeS': '4D2274', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-09-11 05:00Z',
#     'local': '2024-09-11 07:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:09Z',
#     'local': '2024-09-11 07:09+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:10Z',
#     'local': '2024-09-11 07:10+02:00'},
#    'terminal': '3',
#    'checkInDesk': '351-372',
#    'gate': 'F25',
#    'runway': '29',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:10Z',
#     'local': '2024-09-11 08:10+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:03Z',
#     'local': '2024-09-11 08:03+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:03Z',
#     'local': '2024-09-11 08:03+02:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'OS 223',
#   'callSign': 'AUA223',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LBQ', 'modeS': '44004F', 'model': 'Airbus A320'},
#   'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#  {'departure': {'airport': {'icao': 'LIME',
#     'iata': 'BGY',
#     'name': 'Bergamo',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-09-11 04:40Z',
#     'local': '2024-09-11 06:40+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:55Z',
#     'local': '2024-09-11 06:55+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:55Z',
#     'local': '2024-09-11 06:55+02:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:20Z',
#     'local': '2024-09-11 08:20+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:06Z',
#     'local': '2024-09-11 08:06+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:07Z',
#     'local': '2024-09-11 08:07+02:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C3',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 3312',
#   'callSign': 'RYR7KH',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-QCD', 'modeS': '4D2242', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LIML',
#     'iata': 'LIN',
#     'name': 'Milan',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-09-11 04:55Z',
#     'local': '2024-09-11 06:55+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:51Z',
#     'local': '2024-09-11 06:51+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:51Z',
#     'local': '2024-09-11 06:51+02:00'},
#    'terminal': 'NULL',
#    'runway': '36',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:35Z',
#     'local': '2024-09-11 08:35+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:09Z',
#     'local': '2024-09-11 08:09+02:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5068',
#   'callSign': 'EJU5068',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LIML',
#     'iata': 'LIN',
#     'name': 'Milan',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-09-11 04:55Z',
#     'local': '2024-09-11 06:55+02:00'},
#    'revisedTime': {'utc': '2024-09-11 04:51Z',
#     'local': '2024-09-11 06:51+02:00'},
#    'runwayTime': {'utc': '2024-09-11 04:51Z',
#     'local': '2024-09-11 06:51+02:00'},
#    'terminal': 'NULL',
#    'runway': '36',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:35Z',
#     'local': '2024-09-11 08:35+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:09Z',
#     'local': '2024-09-11 08:09+02:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5068',
#   'callSign': 'EJU5068',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 05:00Z',
#     'local': '2024-09-11 07:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:00Z',
#     'local': '2024-09-11 07:00+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:28Z',
#     'local': '2024-09-11 07:28+02:00'},
#    'terminal': '2',
#    'runway': '26R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:05Z',
#     'local': '2024-09-11 08:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:11Z',
#     'local': '2024-09-11 08:11+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:11Z',
#     'local': '2024-09-11 08:11+02:00'},
#    'terminal': '1',
#    'gate': 'A17',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1928',
#   'callSign': 'DLH7N',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIRY', 'modeS': '3C6659', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LDDU',
#     'iata': 'DBV',
#     'name': 'Dubrovnik',
#     'timeZone': 'Europe/Zagreb'},
#    'scheduledTime': {'utc': '2024-09-11 04:30Z',
#     'local': '2024-09-11 06:30+02:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:40Z',
#     'local': '2024-09-11 08:40+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:17Z',
#     'local': '2024-09-11 08:17+02:00'},
#    'terminal': '2',
#    'gate': 'Z34',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 5979',
#   'callSign': 'RYR5W',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SP-RZE',
#    'modeS': '48C2A4',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LFPO',
#     'iata': 'ORY',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-09-11 05:10Z',
#     'local': '2024-09-11 07:10+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:08Z',
#     'local': '2024-09-11 07:08+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:08Z',
#     'local': '2024-09-11 07:08+02:00'},
#    'terminal': '1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:50Z',
#     'local': '2024-09-11 08:50+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:22Z',
#     'local': '2024-09-11 08:22+02:00'},
#    'terminal': '1',
#    'gate': 'A35',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 4897',
#   'callSign': 'EJU42RU',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ING', 'modeS': '440005', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LFPO',
#     'iata': 'ORY',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-09-11 05:10Z',
#     'local': '2024-09-11 07:10+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:08Z',
#     'local': '2024-09-11 07:08+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:08Z',
#     'local': '2024-09-11 07:08+02:00'},
#    'terminal': '1',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:50Z',
#     'local': '2024-09-11 08:50+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:22Z',
#     'local': '2024-09-11 08:22+02:00'},
#    'terminal': '1',
#    'gate': 'A35',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 4897',
#   'callSign': 'EJU42RU',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ING', 'modeS': '440005', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LIPZ',
#     'iata': 'VCE',
#     'name': 'Venice',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-09-11 05:10Z',
#     'local': '2024-09-11 07:10+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:55Z',
#     'local': '2024-09-11 08:55+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:24Z',
#     'local': '2024-09-11 08:24+02:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 4075',
#   'callSign': 'EJU82KJ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LKK', 'modeS': '44061B', 'model': 'Airbus A319'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LIPZ',
#     'iata': 'VCE',
#     'name': 'Venice',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-09-11 05:10Z',
#     'local': '2024-09-11 07:10+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:55Z',
#     'local': '2024-09-11 08:55+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:24Z',
#     'local': '2024-09-11 08:24+02:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 4075',
#   'callSign': 'EJU82KJ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LKK', 'modeS': '44061B', 'model': 'Airbus A319'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LTAI',
#     'iata': 'AYT',
#     'name': 'Antalya',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-09-11 03:05Z',
#     'local': '2024-09-11 06:05+03:00'},
#    'revisedTime': {'utc': '2024-09-11 03:05Z',
#     'local': '2024-09-11 06:05+03:00'},
#    'runwayTime': {'utc': '2024-09-11 03:37Z',
#     'local': '2024-09-11 06:37+03:00'},
#    'terminal': '1',
#    'checkInDesk': '110-112',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:35Z',
#     'local': '2024-09-11 08:35+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:28Z',
#     'local': '2024-09-11 08:28+02:00'},
#    'terminal': '1',
#    'gate': 'X03',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'PC 5067',
#   'callSign': 'PGT4WR',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-NBE',
#    'modeS': '4BB845',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#  {'departure': {'airport': {'icao': 'OEJN',
#     'iata': 'JED',
#     'name': 'Jeddah',
#     'timeZone': 'Asia/Riyadh'},
#    'scheduledTime': {'utc': '2024-09-11 00:55Z',
#     'local': '2024-09-11 03:55+03:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:45Z',
#     'local': '2024-09-11 08:45+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:31Z',
#     'local': '2024-09-11 08:31+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:33Z',
#     'local': '2024-09-11 08:33+02:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'XY 643',
#   'callSign': 'KNE643',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HZ-NS69',
#    'modeS': '717C70',
#    'model': 'Airbus A320 NEO'},
#   'airline': {'name': 'flynas', 'iata': 'XY', 'icao': 'KNE'}},
#  {'departure': {'airport': {'icao': 'EGKK',
#     'iata': 'LGW',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-09-11 05:05Z',
#     'local': '2024-09-11 06:05+01:00'},
#    'revisedTime': {'utc': '2024-09-11 05:10Z',
#     'local': '2024-09-11 06:10+01:00'},
#    'runwayTime': {'utc': '2024-09-11 05:12Z',
#     'local': '2024-09-11 06:12+01:00'},
#    'terminal': 'N',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:00Z',
#     'local': '2024-09-11 09:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:37Z',
#     'local': '2024-09-11 08:37+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:43Z',
#     'local': '2024-09-11 08:43+02:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 8629',
#   'callSign': 'EZY19TC',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-EZDF', 'modeS': '405635', 'model': 'Airbus A319'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-09-11 05:20Z',
#     'local': '2024-09-11 07:20+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:20Z',
#     'local': '2024-09-11 07:20+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:38Z',
#     'local': '2024-09-11 07:38+02:00'},
#    'terminal': 'NULL',
#    'checkInDesk': '1',
#    'gate': 'A71',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:45Z',
#     'local': '2024-09-11 08:45+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:38Z',
#     'local': '2024-09-11 08:38+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:44Z',
#     'local': '2024-09-11 08:44+02:00'},
#    'terminal': '1',
#    'gate': 'B07',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'LX 974',
#   'callSign': 'SWR97Y',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'HB-IOD', 'modeS': '4B168F', 'model': 'Airbus A321'},
#   'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#  {'departure': {'airport': {'icao': 'EDDF',
#     'iata': 'FRA',
#     'name': 'Frankfurt-am-Main',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 05:45Z',
#     'local': '2024-09-11 07:45+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:45Z',
#     'local': '2024-09-11 07:45+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:57Z',
#     'local': '2024-09-11 07:57+02:00'},
#    'terminal': '1',
#    'checkInDesk': '259-335',
#    'gate': 'A18',
#    'runway': '25C',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:55Z',
#     'local': '2024-09-11 08:55+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:43Z',
#     'local': '2024-09-11 08:43+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:43Z',
#     'local': '2024-09-11 08:43+02:00'},
#    'terminal': '1',
#    'gate': 'B20',
#    'baggageBelt': 'B3',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 174',
#   'callSign': 'DLH4PH',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AIST', 'modeS': '3C6674', 'model': 'Airbus A321'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LIRN',
#     'iata': 'NAP',
#     'name': 'Nápoli',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-09-11 05:00Z',
#     'local': '2024-09-11 07:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:00Z',
#     'local': '2024-09-11 07:00+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:00Z',
#     'local': '2024-09-11 07:00+02:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:20Z',
#     'local': '2024-09-11 09:20+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:46Z',
#     'local': '2024-09-11 08:46+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:48Z',
#     'local': '2024-09-11 08:48+02:00'},
#    'terminal': '1',
#    'gate': 'A36',
#    'baggageBelt': 'A4',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 4265',
#   'callSign': 'EJU4265',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IVQ', 'modeS': '4400C8', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LIRN',
#     'iata': 'NAP',
#     'name': 'Nápoli',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-09-11 05:00Z',
#     'local': '2024-09-11 07:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:00Z',
#     'local': '2024-09-11 07:00+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:00Z',
#     'local': '2024-09-11 07:00+02:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:20Z',
#     'local': '2024-09-11 09:20+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:46Z',
#     'local': '2024-09-11 08:46+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:48Z',
#     'local': '2024-09-11 08:48+02:00'},
#    'terminal': '1',
#    'gate': 'A36',
#    'baggageBelt': 'A4',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 4265',
#   'callSign': 'EJU4265',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IVQ', 'modeS': '4400C8', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LTBJ',
#     'iata': 'ADB',
#     'name': 'İzmir',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-09-11 01:25Z',
#     'local': '2024-09-11 04:25+03:00'},
#    'revisedTime': {'utc': '2024-09-11 04:21Z',
#     'local': '2024-09-11 07:21+03:00'},
#    'runwayTime': {'utc': '2024-09-11 04:20Z',
#     'local': '2024-09-11 07:20+03:00'},
#    'terminal': 'I',
#    'checkInDesk': '22',
#    'gate': '104',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 04:30Z',
#     'local': '2024-09-11 06:30+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:50Z',
#     'local': '2024-09-11 08:50+02:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'XQ 966',
#   'callSign': 'SXS5D',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-SPO', 'modeS': '4BCE0F', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#  {'departure': {'airport': {'icao': 'EDDM',
#     'iata': 'MUC',
#     'name': 'Munich',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 06:00Z',
#     'local': '2024-09-11 08:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:00Z',
#     'local': '2024-09-11 08:00+02:00'},
#    'terminal': '2',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:05Z',
#     'local': '2024-09-11 09:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:52Z',
#     'local': '2024-09-11 08:52+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:53Z',
#     'local': '2024-09-11 08:53+02:00'},
#    'terminal': '1',
#    'gate': 'A17',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'LH 1930',
#   'callSign': 'DLH5LW',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AILX', 'modeS': '3C6598', 'model': 'Airbus A319'},
#   'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#  {'departure': {'airport': {'icao': 'LFPG',
#     'iata': 'CDG',
#     'name': 'Paris',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:45Z',
#     'local': '2024-09-11 07:45+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:45Z',
#     'local': '2024-09-11 07:45+02:00'},
#    'terminal': '2F',
#    'runway': '27L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 06:55Z',
#     'local': '2024-09-11 08:55+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:54Z',
#     'local': '2024-09-11 08:54+02:00'},
#    'terminal': '1',
#    'gate': 'A30',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'AF 1434',
#   'callSign': 'AFR95ZE',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'F-HDRF', 'modeS': '398E25', 'model': 'Airbus A320'},
#   'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#  {'departure': {'airport': {'icao': 'ENGM',
#     'iata': 'OSL',
#     'name': 'Oslo',
#     'timeZone': 'Europe/Oslo'},
#    'scheduledTime': {'utc': '2024-09-11 05:30Z',
#     'local': '2024-09-11 07:30+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:21Z',
#     'local': '2024-09-11 07:21+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:36Z',
#     'local': '2024-09-11 07:36+02:00'},
#    'terminal': 'NULL',
#    'checkInDesk': '123',
#    'gate': 'D8',
#    'runway': '19L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:05Z',
#     'local': '2024-09-11 09:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:59Z',
#     'local': '2024-09-11 08:59+02:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'DY 1102',
#   'callSign': 'NOZ2XM',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'LN-ENO', 'modeS': '47A32E', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 06:10Z',
#     'local': '2024-09-11 08:10+02:00'},
#    'terminal': '1',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:20Z',
#     'local': '2024-09-11 09:20+02:00'},
#    'revisedTime': {'utc': '2024-09-11 07:12Z',
#     'local': '2024-09-11 09:12+02:00'},
#    'terminal': '1',
#    'gate': 'A32',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8059',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWN', 'modeS': '3C5EEE', 'model': 'Airbus A319'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-09-11 06:19Z',
#     'local': '2024-09-11 08:19+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:19Z',
#     'local': '2024-09-11 08:19+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:19Z',
#     'local': '2024-09-11 08:19+02:00'},
#    'runway': '29',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:18Z',
#     'local': '2024-09-11 09:18+02:00'},
#    'revisedTime': {'utc': '2024-09-11 07:18Z',
#     'local': '2024-09-11 09:18+02:00'},
#    'runwayTime': {'utc': '2024-09-11 07:18Z',
#     'local': '2024-09-11 09:18+02:00'},
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'OEFLL',
#   'callSign': 'OEFLL',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-XOH',
#    'modeS': '44015B',
#    'model': 'Eurocopter AS350'},
#   'airline': {'name': 'OEFLL'}},
#  {'departure': {'airport': {'icao': 'LFMN',
#     'iata': 'NCE',
#     'name': 'Nice',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'revisedTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'runwayTime': {'utc': '2024-09-11 05:15Z',
#     'local': '2024-09-11 07:15+02:00'},
#    'runway': '04R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:20Z',
#     'local': '2024-09-11 09:20+02:00'},
#    'revisedTime': {'utc': '2024-09-11 07:20Z',
#     'local': '2024-09-11 09:20+02:00'},
#    'runwayTime': {'utc': '2024-09-11 07:20Z',
#     'local': '2024-09-11 09:20+02:00'},
#    'quality': ['Basic', 'Live']},
#   'number': 'LWG 10B',
#   'callSign': 'LWG10B',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-FOM', 'modeS': '4D2091', 'model': 'EMB-500'},
#   'airline': {'name': 'LWG'}},
#  {'departure': {'airport': {'icao': 'LTFM',
#     'iata': 'IST',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-09-11 04:30Z',
#     'local': '2024-09-11 07:30+03:00'},
#    'revisedTime': {'utc': '2024-09-11 04:40Z',
#     'local': '2024-09-11 07:40+03:00'},
#    'runwayTime': {'utc': '2024-09-11 05:17Z',
#     'local': '2024-09-11 08:17+03:00'},
#    'terminal': 'NULL',
#    'checkInDesk': 'E-F',
#    'gate': 'D6',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:20Z',
#     'local': '2024-09-11 09:20+02:00'},
#    'revisedTime': {'utc': '2024-09-11 07:20Z',
#     'local': '2024-09-11 09:20+02:00'},
#    'terminal': '1',
#    'gate': 'X01',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'TK 1721',
#   'callSign': 'THY3CS',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-LLZ', 'modeS': '4BB19A', 'model': 'Boeing 787-9'},
#   'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#  {'departure': {'airport': {'icao': 'EDDK',
#     'iata': 'CGN',
#     'name': 'Cologne',
#     'timeZone': 'Europe/Berlin'},
#    'scheduledTime': {'utc': '2024-09-11 06:26Z',
#     'local': '2024-09-11 08:26+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:26Z',
#     'local': '2024-09-11 08:26+02:00'},
#    'runwayTime': {'utc': '2024-09-11 06:26Z',
#     'local': '2024-09-11 08:26+02:00'},
#    'runway': '24',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:21Z',
#     'local': '2024-09-11 09:21+02:00'},
#    'revisedTime': {'utc': '2024-09-11 07:21Z',
#     'local': '2024-09-11 09:21+02:00'},
#    'runwayTime': {'utc': '2024-09-11 07:21Z',
#     'local': '2024-09-11 09:21+02:00'},
#    'quality': ['Basic', 'Live']},
#   'number': '4U 9RX',
#   'callSign': 'GWI9RX',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-AGWN', 'modeS': '3C5EEE', 'model': 'Airbus A319'},
#   'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#  {'departure': {'airport': {'name': 'Unknown'}, 'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:24Z',
#     'local': '2024-09-11 09:24+02:00'},
#    'revisedTime': {'utc': '2024-09-11 07:24Z',
#     'local': '2024-09-11 09:24+02:00'},
#    'runwayTime': {'utc': '2024-09-11 07:24Z',
#     'local': '2024-09-11 09:24+02:00'},
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'VJT 527',
#   'callSign': 'VJT527',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-VLK',
#    'modeS': '4D22D6',
#    'model': 'Bombardier Challenger 600'},
#   'airline': {'name': 'VistaJet', 'icao': 'VJT'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-09-11 06:05Z',
#     'local': '2024-09-11 08:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:05Z',
#     'local': '2024-09-11 08:05+02:00'},
#    'checkInDesk': '3',
#    'gate': 'B41',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:40Z',
#     'local': '2024-09-11 09:40+02:00'},
#    'revisedTime': {'utc': '2024-09-11 07:25Z',
#     'local': '2024-09-11 09:25+02:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5188',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDD', 'modeS': '440CCC', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LSZH',
#     'iata': 'ZRH',
#     'name': 'Zurich',
#     'timeZone': 'Europe/Zurich'},
#    'scheduledTime': {'utc': '2024-09-11 06:05Z',
#     'local': '2024-09-11 08:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 06:05Z',
#     'local': '2024-09-11 08:05+02:00'},
#    'terminal': 'NULL',
#    'checkInDesk': '3',
#    'gate': 'B41',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 07:40Z',
#     'local': '2024-09-11 09:40+02:00'},
#    'revisedTime': {'utc': '2024-09-11 07:25Z',
#     'local': '2024-09-11 09:25+02:00'},
#    'terminal': '1',
#    'gate': 'A34',
#    'baggageBelt': 'A4',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5188',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-IDD', 'modeS': '440CCC', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'EDDL',
#     'iata': 'DUS',
#     'name': 'Düsseldorf',
# ...
#   'number': 'U2 5082',
#   'callSign': 'EJU34TY',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICN', 'modeS': '44001F', 'model': 'Airbus A320'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LIRF',
#     'iata': 'FCO',
#     'name': 'Rome',
#     'timeZone': 'Europe/Rome'},
#    'scheduledTime': {'utc': '2024-09-11 07:00Z',
#     'local': '2024-09-11 09:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 07:17Z',
#     'local': '2024-09-11 09:17+02:00'},
#    'runwayTime': {'utc': '2024-09-11 07:17Z',
#     'local': '2024-09-11 09:17+02:00'},
#    'terminal': '1',
#    'runway': '25',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:15Z',
#     'local': '2024-09-11 11:15+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:06Z',
#     'local': '2024-09-11 11:06+02:00'},
#    'terminal': '1',
#    'gate': 'A37',
#    'baggageBelt': 'A3',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5082',
#   'callSign': 'EJU34TY',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-ICN', 'modeS': '44001F', 'model': 'Airbus A320'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'EGLC',
#     'iata': 'LCY',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-09-11 07:25Z',
#     'local': '2024-09-11 08:25+01:00'},
#    'revisedTime': {'utc': '2024-09-11 07:43Z',
#     'local': '2024-09-11 08:43+01:00'},
#    'runwayTime': {'utc': '2024-09-11 07:48Z',
#     'local': '2024-09-11 08:48+01:00'},
#    'terminal': 'NULL',
#    'gate': '4',
#    'runway': '27',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:10Z',
#     'local': '2024-09-11 11:10+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:08Z',
#     'local': '2024-09-11 11:08+02:00'},
#    'runwayTime': {'utc': '2024-09-11 09:09Z',
#     'local': '2024-09-11 11:09+02:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'BA 8491',
#   'callSign': 'CFE76JZ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-LCAD', 'modeS': '40799C', 'model': 'Embraer 190'},
#   'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'LFSB',
#     'iata': 'BSL',
#     'name': 'Bâle/Mulhouse',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-09-11 08:00Z',
#     'local': '2024-09-11 10:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 08:03Z',
#     'local': '2024-09-11 10:03+02:00'},
#    'runwayTime': {'utc': '2024-09-11 08:04Z',
#     'local': '2024-09-11 10:04+02:00'},
#    'terminal': 'NULL',
#    'checkInDesk': '42-50',
#    'gate': '35',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:30Z',
#     'local': '2024-09-11 11:30+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:13Z',
#     'local': '2024-09-11 11:13+02:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A4',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'U2 5535',
#   'callSign': 'EJU75ZB',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LQF', 'modeS': '4403F0', 'model': 'Airbus A319'},
#   'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#  {'departure': {'airport': {'icao': 'LFSB',
#     'iata': 'BSL',
#     'name': 'Bâle/Mulhouse',
#     'timeZone': 'Europe/Paris'},
#    'scheduledTime': {'utc': '2024-09-11 08:00Z',
#     'local': '2024-09-11 10:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 08:03Z',
#     'local': '2024-09-11 10:03+02:00'},
#    'runwayTime': {'utc': '2024-09-11 08:04Z',
#     'local': '2024-09-11 10:04+02:00'},
#    'checkInDesk': '42-50',
#    'gate': '35',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:30Z',
#     'local': '2024-09-11 11:30+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:13Z',
#     'local': '2024-09-11 11:13+02:00'},
#    'terminal': '1',
#    'gate': 'A38',
#    'baggageBelt': 'A4',
#    'runway': '25L',
#    'quality': ['Basic', 'Live']},
#   'number': 'EC 5535',
#   'callSign': 'EJU75ZB',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsCodeshared',
#   'isCargo': False,
#   'aircraft': {'reg': 'OE-LQF', 'modeS': '4403F0', 'model': 'Airbus A319'},
#   'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#  {'departure': {'airport': {'icao': 'LOWW',
#     'iata': 'VIE',
#     'name': 'Vienna',
#     'timeZone': 'Europe/Vienna'},
#    'scheduledTime': {'utc': '2024-09-11 07:55Z',
#     'local': '2024-09-11 09:55+02:00'},
#    'revisedTime': {'utc': '2024-09-11 08:25Z',
#     'local': '2024-09-11 10:25+02:00'},
#    'runwayTime': {'utc': '2024-09-11 08:25Z',
#     'local': '2024-09-11 10:25+02:00'},
#    'terminal': '1',
#    'checkInDesk': '151-162',
#    'gate': 'C42',
#    'runway': '29',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:15Z',
#     'local': '2024-09-11 11:15+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:15Z',
#     'local': '2024-09-11 11:15+02:00'},
#    'terminal': '1',
#    'gate': 'A35',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'EW 8751',
#   'callSign': 'EWG2NY',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-MLR', 'modeS': '4D23A1', 'model': 'Airbus A320'},
#   'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#  {'departure': {'airport': {'icao': 'LGTS',
#     'iata': 'SKG',
#     'name': 'Thessaloniki',
#     'timeZone': 'Europe/Athens'},
#    'scheduledTime': {'utc': '2024-09-11 06:55Z',
#     'local': '2024-09-11 09:55+03:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:25Z',
#     'local': '2024-09-11 11:25+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:16Z',
#     'local': '2024-09-11 11:16+02:00'},
#    'terminal': '2',
#    'gate': 'Z29',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 1147',
#   'callSign': 'RYR3KZ',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': '9H-VVK',
#    'modeS': '4D24CC',
#    'model': 'Boeing 737 MAX 8'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'BIKF',
#     'iata': 'KEF',
#     'name': 'Reykjavik',
#     'timeZone': 'Atlantic/Reykjavik'},
#    'scheduledTime': {'utc': '2024-09-11 06:00Z',
#     'local': '2024-09-11 06:00+00:00'},
#    'revisedTime': {'utc': '2024-09-11 05:54Z',
#     'local': '2024-09-11 05:54+00:00'},
#    'runwayTime': {'utc': '2024-09-11 06:08Z',
#     'local': '2024-09-11 06:08+00:00'},
#    'terminal': 'NULL',
#    'gate': 'C21',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:30Z',
#     'local': '2024-09-11 11:30+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:21Z',
#     'local': '2024-09-11 11:21+02:00'},
#    'terminal': '2',
#    'gate': 'Z34',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'OG 700',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TF-PPD',
#    'modeS': '4CC564',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'Ghodawat Enterprises', 'iata': 'OG', 'icao': 'SDG'}},
#  {'departure': {'airport': {'icao': 'EHAM',
#     'iata': 'AMS',
#     'name': 'Amsterdam',
#     'timeZone': 'Europe/Amsterdam'},
#    'scheduledTime': {'utc': '2024-09-11 08:15Z',
#     'local': '2024-09-11 10:15+02:00'},
#    'revisedTime': {'utc': '2024-09-11 08:25Z',
#     'local': '2024-09-11 10:25+02:00'},
#    'terminal': '1',
#    'checkInDesk': '6-8',
#    'gate': 'C12',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:30Z',
#     'local': '2024-09-11 11:30+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:26Z',
#     'local': '2024-09-11 11:26+02:00'},
#    'terminal': '1',
#    'gate': 'A31',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'KL 1775',
#   'callSign': 'KLM1775',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'PH-BGB', 'modeS': '484559', 'model': 'Boeing 737'},
#   'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#  {'departure': {'airport': {'icao': 'ESSA',
#     'iata': 'ARN',
#     'name': 'Stockholm',
#     'timeZone': 'Europe/Stockholm'},
#    'scheduledTime': {'utc': '2024-09-11 08:00Z',
#     'local': '2024-09-11 10:00+02:00'},
#    'revisedTime': {'utc': '2024-09-11 07:58Z',
#     'local': '2024-09-11 09:58+02:00'},
#    'runwayTime': {'utc': '2024-09-11 08:08Z',
#     'local': '2024-09-11 10:08+02:00'},
#    'terminal': '5',
#    'checkInDesk': '18-0',
#    'gate': 'D11',
#    'runway': '19R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:35Z',
#     'local': '2024-09-11 11:35+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:31Z',
#     'local': '2024-09-11 11:31+02:00'},
#    'terminal': '2',
#    'gate': 'Z32',
#    'baggageBelt': 'C2',
#    'quality': ['Basic', 'Live']},
#   'number': 'DY 886',
#   'callSign': 'NOZ886',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SE-RPK', 'modeS': '4ACA0B', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#  {'departure': {'airport': {'icao': 'LTFJ',
#     'iata': 'SAW',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'quality': []},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:33Z',
#     'local': '2024-09-11 11:33+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:33Z',
#     'local': '2024-09-11 11:33+02:00'},
#    'runwayTime': {'utc': '2024-09-11 09:33Z',
#     'local': '2024-09-11 11:33+02:00'},
#    'quality': ['Basic', 'Live']},
#   'number': 'TKJ 86N',
#   'callSign': 'TKJ86N',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-GPE', 'modeS': '4B9E05', 'model': 'Airbus A321'},
#   'airline': {'name': 'TKJ'}},
#  {'departure': {'airport': {'icao': 'LTFJ',
#     'iata': 'SAW',
#     'name': 'Istanbul',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-09-11 06:20Z',
#     'local': '2024-09-11 09:20+03:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:25Z',
#     'local': '2024-09-11 11:25+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:34Z',
#     'local': '2024-09-11 11:34+02:00'},
#    'terminal': '1',
#    'gate': 'N01',
#    'baggageBelt': 'B4',
#    'quality': ['Basic', 'Live']},
#   'number': 'VF 57',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-GPE', 'modeS': '4B9E05', 'model': 'Airbus A321'},
#   'airline': {'name': 'Ajet', 'iata': 'VF', 'icao': 'VLU'}},
#  {'departure': {'airport': {'icao': 'EGLL',
#     'iata': 'LHR',
#     'name': 'London',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-09-11 07:45Z',
#     'local': '2024-09-11 08:45+01:00'},
#    'revisedTime': {'utc': '2024-09-11 08:19Z',
#     'local': '2024-09-11 09:19+01:00'},
#    'runwayTime': {'utc': '2024-09-11 08:20Z',
#     'local': '2024-09-11 09:20+01:00'},
#    'terminal': '5',
#    'checkInDesk': 'D',
#    'runway': '27L',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:35Z',
#     'local': '2024-09-11 11:35+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:41Z',
#     'local': '2024-09-11 11:41+02:00'},
#    'runwayTime': {'utc': '2024-09-11 09:43Z',
#     'local': '2024-09-11 11:43+02:00'},
#    'terminal': '1',
#    'gate': 'X03',
#    'baggageBelt': 'A1',
#    'quality': ['Basic', 'Live']},
#   'number': 'BA 982',
#   'callSign': 'BAW982G',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'G-EUPT', 'modeS': '4008B4', 'model': 'Airbus A319'},
#   'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#  {'departure': {'airport': {'icao': 'LBBG',
#     'iata': 'BOJ',
#     'name': 'Burgas',
#     'timeZone': 'Europe/Sofia'},
#    'scheduledTime': {'utc': '2024-09-11 07:20Z',
#     'local': '2024-09-11 10:20+03:00'},
#    'terminal': 'NULL',
#    'quality': ['Basic']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 10:05Z',
#     'local': '2024-09-11 12:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:44Z',
#     'local': '2024-09-11 11:44+02:00'},
#    'runwayTime': {'utc': '2024-09-11 09:46Z',
#     'local': '2024-09-11 11:46+02:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B2',
#    'quality': ['Basic', 'Live']},
#   'number': 'SR 7401',
#   'callSign': 'SDR70MN',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'D-ASMR', 'modeS': '3C0936', 'model': 'Airbus A320'},
#   'airline': {'name': 'SundAir', 'iata': 'SR', 'icao': 'SDR'}},
#  {'departure': {'airport': {'icao': 'EGPH',
#     'iata': 'EDI',
#     'name': 'Edinburgh',
#     'timeZone': 'Europe/London'},
#    'scheduledTime': {'utc': '2024-09-11 08:05Z',
#     'local': '2024-09-11 09:05+01:00'},
#    'revisedTime': {'utc': '2024-09-11 08:09Z',
#     'local': '2024-09-11 09:09+01:00'},
#    'runwayTime': {'utc': '2024-09-11 08:09Z',
#     'local': '2024-09-11 09:09+01:00'},
#    'terminal': 'NULL',
#    'runway': '24',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 10:05Z',
#     'local': '2024-09-11 12:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:49Z',
#     'local': '2024-09-11 11:49+02:00'},
#    'terminal': '2',
#    'gate': 'Z42',
#    'baggageBelt': 'C1',
#    'quality': ['Basic', 'Live']},
#   'number': 'FR 2376',
#   'callSign': 'RYR2376',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'EI-EKR', 'modeS': '4CA811', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#  {'departure': {'airport': {'icao': 'LTAI',
#     'iata': 'AYT',
#     'name': 'Antalya',
#     'timeZone': 'Europe/Istanbul'},
#    'scheduledTime': {'utc': '2024-09-11 06:00Z',
#     'local': '2024-09-11 09:00+03:00'},
#    'revisedTime': {'utc': '2024-09-11 06:30Z',
#     'local': '2024-09-11 09:30+03:00'},
#    'runwayTime': {'utc': '2024-09-11 07:00Z',
#     'local': '2024-09-11 10:00+03:00'},
#    'terminal': '1',
#    'checkInDesk': '129-131',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:35Z',
#     'local': '2024-09-11 11:35+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:50Z',
#     'local': '2024-09-11 11:50+02:00'},
#    'terminal': '1',
#    'gate': 'X01',
#    'baggageBelt': 'A2',
#    'quality': ['Basic', 'Live']},
#   'number': 'XQ 160',
#   'callSign': 'SXS2SR',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'TC-SEJ', 'modeS': '4BCCAA', 'model': 'Boeing 737-800'},
#   'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#  {'departure': {'airport': {'icao': 'ESSA',
#     'iata': 'ARN',
#     'name': 'Stockholm',
#     'timeZone': 'Europe/Stockholm'},
#    'scheduledTime': {'utc': '2024-09-11 08:05Z',
#     'local': '2024-09-11 10:05+02:00'},
#    'revisedTime': {'utc': '2024-09-11 08:01Z',
#     'local': '2024-09-11 10:01+02:00'},
#    'runwayTime': {'utc': '2024-09-11 08:12Z',
#     'local': '2024-09-11 10:12+02:00'},
#    'terminal': '5',
#    'checkInDesk': '71-80',
#    'gate': 'E8',
#    'runway': '19R',
#    'quality': ['Basic', 'Live']},
#   'arrival': {'scheduledTime': {'utc': '2024-09-11 09:40Z',
#     'local': '2024-09-11 11:40+02:00'},
#    'revisedTime': {'utc': '2024-09-11 09:53Z',
#     'local': '2024-09-11 11:53+02:00'},
#    'terminal': '1',
#    'gate': 'S01',
#    'baggageBelt': 'B3',
#    'runway': '25R',
#    'quality': ['Basic', 'Live']},
#   'number': 'SK 2677',
#   'callSign': 'SAS2677',
#   'status': 'Arrived',
#   'codeshareStatus': 'IsOperator',
#   'isCargo': False,
#   'aircraft': {'reg': 'SE-ROI',
#    'modeS': '4AC9E9',
#    'model': 'Airbus A321 (Sharklets)'},
#   'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}}]

# %%
flights_json["arrivals"][0]
# Out:
# {'departure': {'airport': {'icao': 'LTFH',
#    'iata': 'SZF',
#    'name': 'Samsun',
#    'timeZone': 'Europe/Istanbul'},
#   'scheduledTime': {'utc': '2024-09-11 01:10Z',
#    'local': '2024-09-11 04:10+03:00'},
#   'terminal': 'NULL',
#   'quality': ['Basic']},
#  'arrival': {'scheduledTime': {'utc': '2024-09-11 04:45Z',
#    'local': '2024-09-11 06:45+02:00'},
#   'revisedTime': {'utc': '2024-09-11 04:11Z',
#    'local': '2024-09-11 06:11+02:00'},
#   'runwayTime': {'utc': '2024-09-11 04:18Z',
#    'local': '2024-09-11 06:18+02:00'},
#   'terminal': '1',
#   'gate': 'N01',
#   'baggageBelt': 'B3',
#   'quality': ['Basic', 'Live']},
#  'number': 'XQ 1768',
#  'callSign': 'SXS6JD',
#  'status': 'Arrived',
#  'codeshareStatus': 'IsOperator',
#  'isCargo': False,
#  'aircraft': {'reg': 'TC-SPJ', 'modeS': '4BCE0A', 'model': 'Boeing 737'},
#  'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}}

# %%
flights_json["arrivals"][0].keys()
# Out:
# dict_keys(['departure', 'arrival', 'number', 'callSign', 'status', 'codeshareStatus', 'isCargo', 'aircraft', 'airline'])

# %%
flight_items = [] # Empty list

for item in flights_json["arrivals"]: # Referring to arrivals dict in flights_json
    flight_item = {
        "arrival airport_icao" : icao, 
        "departure_airport_icao": item["departure"]["airport"].get("icao", None),  #item["Key"]["Value"].get("1st element")
        "scheduled_arrival_time" : item["arrival"]["scheduledTime"].get("local", None),
        "arrival_terminal" : item['arrival'].get('terminal', None),
        "flight_number" : item.get("number", None)
    } # Defining the elements in for loop completed
    
    flight_items.append(flight_item) # The one to which we append comes first followed by one getting appended
    
flights_df = pd.DataFrame(flight_items)

flights_df.head()
# Out:
#   arrival airport_icao departure_airport_icao  scheduled_arrival_time  \
# 0                 EDDB                   LTFH  2024-09-11 06:45+02:00
# 1                 EDDB                   KEWR  2024-09-11 07:15+02:00
# 2                 EDDB                   OTHH  2024-09-11 07:20+02:00
# 3                 EDDB                   ZBAA  2024-09-11 06:45+02:00
# 4                 EDDB                   LOWW  2024-09-11 07:30+02:00
#
#   arrival_terminal flight_number
# 0                1       XQ 1768
# 1                1        UA 962
# 2                1         QR 79
# 3                1        HU 489
# 4                1        OS 221

# %%
flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6] # Removing last 6 characters from the string
flights_df.head()
# Out:
#   arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                 EDDB                   LTFH       2024-09-11 06:45
# 1                 EDDB                   KEWR       2024-09-11 07:15
# 2                 EDDB                   OTHH       2024-09-11 07:20
# 3                 EDDB                   ZBAA       2024-09-11 06:45
# 4                 EDDB                   LOWW       2024-09-11 07:30
#
#   flight_number
# 0       XQ 1768
# 1        UA 962
# 2         QR 79
# 3        HU 489
# 4        OS 221

# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from pytz import timezone

def get_flight_data(icao_list):
  api_key = RAPIDAPI_KEY,

  berlin_timezone = timezone('Europe/Berlin')
  today = datetime.now(berlin_timezone).date()
  tomorrow = (today + timedelta(days=1))

  flight_items = []

  for icao in icao_list:
    # the api can only make 12 hour calls, therefore, two 12 hour calls make a full day
    # using the nested lists below we can make a morning call and extract the data
    # then make an afternoon call and extract the data
    times = [["00:00","11:59"],
             ["12:00","23:59"]]

    for time in times:
      url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

      querystring = {"withLeg":"true",
                    "direction":"Arrival",
                    "withCancelled":"false",
                    "withCodeshared":"true",
                    "withCargo":"false",
                    "withPrivate":"false"}

      headers = {
                "X-RapidAPI-Key": RAPIDAPI_KEY,
                "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
          }
      response = requests.request("GET",
                                  url,
                                  headers = headers,
                                  params = querystring)

      flights_json = response.json()

      retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

      for item in flights_json["arrivals"]:
        flight_item = {
            "arrival_airport_icao": icao,
            "departure_airport_icao": item["departure"]["airport"].get("icao", None),
            "scheduled_arrival_time": item["arrival"]["scheduledTime"].get("local", None),
            "flight_number": item.get("number", None),
            "data_retrieved_at": retrieval_time
        }

        flight_items.append(flight_item)

  flights_df = pd.DataFrame(flight_items)
  flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6]
  flights_df["scheduled_arrival_time"] = pd.to_datetime(flights_df["scheduled_arrival_time"])
  flights_df["data_retrieved_at"] = pd.to_datetime(flights_df["data_retrieved_at"])

  return flights_df

# %%
icao_list = ["EDDB"]

get_flight_data(icao_list)
# Out:
#     arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                   EDDB                   HEMA    2024-09-12 06:20:00
# 1                   EDDB                   LTBJ    2024-09-12 06:30:00
# 2                   EDDB                   LPCV    2024-09-12 06:45:00
# 3                   EDDB                   ZBAA    2024-09-12 06:45:00
# 4                   EDDB                   KEWR    2024-09-12 07:15:00
# ..                   ...                    ...                    ...
# 345                 EDDB                   LEMD    2024-09-12 23:00:00
# 346                 EDDB                   EGCC    2024-09-12 23:00:00
# 347                 EDDB                   LFPO    2024-09-12 23:10:00
# 348                 EDDB                   LEPA    2024-09-12 23:15:00
# 349                 EDDB                   GCFV    2024-09-12 23:25:00
#
#     flight_number   data_retrieved_at
# 0         SM 2962 2024-09-11 12:51:05
# 1          XQ 966 2024-09-11 12:51:05
# 2         XQ 1774 2024-09-11 12:51:05
# 3          HU 489 2024-09-11 12:51:05
# 4          UA 962 2024-09-11 12:51:05
# ..            ...                 ...
# 345       I2 3674 2024-09-11 12:51:06
# 346       FR 1155 2024-09-11 12:51:06
# 347       TO 3412 2024-09-11 12:51:06
# 348       EW 8595 2024-09-11 12:51:06
# 349       SR 3345 2024-09-11 12:51:06
#
# [350 rows x 5 columns]

# %%
def tomorrows_flight_arrivals(icao_list):

    api_key = "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4"

    berlin_timezone = timezone('Europe/Berlin')
    today = datetime.now(berlin_timezone).date()
    tomorrow = (today + timedelta(days=1))

    list_for_arrivals_df = []

    for icao in icao_list:

        times = [["00:00","11:59"],["12:00","23:59"]]

        for time in times:
            url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

            querystring = {"direction":"Arrival","withCancelled":"false"}

            headers = {
                "X-RapidAPI-Key": RAPIDAPI_KEY,
                "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
                }

            response = requests.request("GET", url, headers=headers, params=querystring)
            flights_resp = response.json()

            arrivals_df = pd.json_normalize(flights_resp["arrivals"])[["number", "movement.scheduledTime.local", "movement.airport.name", "movement.airport.icao"]]
            arrivals_df = arrivals_df.rename(columns={"number": "flight_number", "movement.scheduledTime.local": "arrival_time","movement.airport.name": "departure_city", "movement.airport.icao": "departure_airport_icao"})
            arrivals_df["arrival_airport_icao"] = icao
            arrivals_df["data_retrieved_on"] = datetime.now().date()
            arrivals_df = arrivals_df[["arrival_airport_icao", "flight_number", "arrival_time","departure_city", "departure_airport_icao", "data_retrieved_on"]]

            # fixing arrival_time
            arrivals_df["arrival_time"] = arrivals_df["arrival_time"].str.split("+").str[0]

            list_for_arrivals_df.append(arrivals_df)

    return pd.concat(list_for_arrivals_df, ignore_index=True)

# %%
icao_list = ["EDDB"]

flights_df = get_flight_data(icao_list)
flights_df
# Out:
#     arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                   EDDB                   HEMA    2024-09-12 06:20:00
# 1                   EDDB                   LTBJ    2024-09-12 06:30:00
# 2                   EDDB                   LPCV    2024-09-12 06:45:00
# 3                   EDDB                   ZBAA    2024-09-12 06:45:00
# 4                   EDDB                   KEWR    2024-09-12 07:15:00
# ..                   ...                    ...                    ...
# 345                 EDDB                   LEMD    2024-09-12 23:00:00
# 346                 EDDB                   LEMD    2024-09-12 23:00:00
# 347                 EDDB                   LFPO    2024-09-12 23:10:00
# 348                 EDDB                   LEPA    2024-09-12 23:15:00
# 349                 EDDB                   GCFV    2024-09-12 23:25:00
#
#     flight_number   data_retrieved_at
# 0         SM 2962 2024-09-11 12:52:35
# 1          XQ 966 2024-09-11 12:52:35
# 2         XQ 1774 2024-09-11 12:52:35
# 3          HU 489 2024-09-11 12:52:35
# 4          UA 962 2024-09-11 12:52:35
# ..            ...                 ...
# 345       IB 3674 2024-09-11 12:52:35
# 346       I2 3674 2024-09-11 12:52:35
# 347       TO 3412 2024-09-11 12:52:35
# 348       EW 8595 2024-09-11 12:52:35
# 349       SR 3345 2024-09-11 12:52:35
#
# [350 rows x 5 columns]

# %%
flights_df
# Out:
#     arrival_airport_icao departure_airport_icao scheduled_arrival_time  \
# 0                   EDDB                   HEMA    2024-09-12 06:20:00
# 1                   EDDB                   LTBJ    2024-09-12 06:30:00
# 2                   EDDB                   LPCV    2024-09-12 06:45:00
# 3                   EDDB                   ZBAA    2024-09-12 06:45:00
# 4                   EDDB                   KEWR    2024-09-12 07:15:00
# ..                   ...                    ...                    ...
# 345                 EDDB                   LEMD    2024-09-12 23:00:00
# 346                 EDDB                   LEMD    2024-09-12 23:00:00
# 347                 EDDB                   LFPO    2024-09-12 23:10:00
# 348                 EDDB                   LEPA    2024-09-12 23:15:00
# 349                 EDDB                   GCFV    2024-09-12 23:25:00
#
#     flight_number   data_retrieved_at
# 0         SM 2962 2024-09-11 12:52:35
# 1          XQ 966 2024-09-11 12:52:35
# 2         XQ 1774 2024-09-11 12:52:35
# 3          HU 489 2024-09-11 12:52:35
# 4          UA 962 2024-09-11 12:52:35
# ..            ...                 ...
# 345       IB 3674 2024-09-11 12:52:35
# 346       I2 3674 2024-09-11 12:52:35
# 347       TO 3412 2024-09-11 12:52:35
# 348       EW 8595 2024-09-11 12:52:35
# 349       SR 3345 2024-09-11 12:52:35
#
# [350 rows x 5 columns]

# %% [markdown]
# ### Push the flights information to sql

# %%
schema = "sql_workshop"
host = "34.77.20.25"
user = "root"
password = "sushma25121998"
port = 3306

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
flights_df.to_sql('flights',
                    if_exists='append',
                    con=connection_string,
                    index=False)
# Out:
# 350
